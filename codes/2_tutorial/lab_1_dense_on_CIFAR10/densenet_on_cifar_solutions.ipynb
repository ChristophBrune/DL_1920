# %% [markdown]
# # Dense networks on CIFAR10
#
# In this lab you will see how well neural networks with fully connected layers perform on a dataset with more complex images. For example, CIFAR10 images have RGB values and thus each pixel corresponds to three values.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data

import time

# %%
# Choose which device to use
use_cuda = True

if use_cuda and torch.cuda.is_available():
  device = torch.device('cuda')
else:
  device = torch.device('cpu')

device
# Out:
# device(type='cuda')

# %% [markdown]
# ### Load the dataset

# %%
import torchvision
import torchvision.transforms as transforms

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))])

trainset = torchvision.datasets.CIFAR10(root='./data_cifar', train=True,
                                        download=True, transform=transform)

testset = torchvision.datasets.CIFAR10(root='./data_cifar', train=False,
                                       download=True, transform=transform)

batch_size = 128
w, h, c = 32, 32, 3  # Width, Height, Nr. of channels for the input images (RGB)
k = 10  # Number of output classes

trainloader = torch.utils.data.DataLoader(trainset,
                                          batch_size=batch_size,
                                          shuffle=True)

testloader = torch.utils.data.DataLoader(testset,
                                         batch_size=batch_size,
                                         shuffle=True)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# 0it [00:00, ?it/s]
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data_cifar/cifar-10-python.tar.gz
# 170500096it [00:03, 43420625.48it/s]
# Extracting ./data_cifar/cifar-10-python.tar.gz to ./data_cifar
# Files already downloaded and verified

# %% [markdown]
# ### Show image examples

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

print(images[0].shape)
print(images.shape)

# show images
imshow(images[0])
imshow(torchvision.utils.make_grid(images))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([3, 32, 32])
# torch.Size([128, 3, 32, 32])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Exercise - Defining an architecture
#
# In this lab we will use fully connected neural networks. Create a dense neural network class that has a variable number of layers and layer sizes.

# %%
class MLP(nn.Module):

  def __init__(self,
               input_size,  # Size of the input. Here we will first flatten the image to a single vector with the 3 * 32 * 32 values in the image 
               layer_sizes,  # A tuple containing the sizes of the hidden layers of the neural network. So to create a NN with two hidden layers with 32 neurons in each layer you'd set layer_sizes=(32,32)
               output_size):  # The size of the network output. CIFAR10 has 10 output classes
    super(MLP, self).__init__()
    shape = (input_size,) + tuple(layer_sizes) + (output_size,)
    self.layers = nn.ModuleList([nn.Linear(shape[i], shape[i + 1]) for i in range(len(shape) - 1)])  # Store the layers in a ModuleList object so they are recognized by pytorch as submodules of this model

  def forward(self, x):
    for layer in self.layers[:-1]:  # Apply relu activation to all but the last layer in the network
      x = F.relu(layer(x))
    return self.layers[-1](x)

# %%
model = MLP(w * h * c, (128, 128), k).to(device)  # Create a new dense neural network with two hidden layers of size 128

print(model)
# Out:
# MLP(
#   (layers): ModuleList(
#     (0): Linear(in_features=3072, out_features=128, bias=True)
#     (1): Linear(in_features=128, out_features=128, bias=True)
#     (2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ### Train the network
#
# Finish the code below so the network is trained on the images. The network should be able to reach an accuracy of about 50%. This is much better than taking random guesses, so the network did learn something. However, it is not a great classifier either. Dense neural networks are usually not the way to go for image classification. Instead, Convolutional Neural Networks are often used. These will be covered in the next lecture.

# %%
start=time.time()

criterion = nn.CrossEntropyLoss()

lr = 0.01
momentum = 0.5
num_epochs = 20

optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum)

for epoch in range(1, num_epochs + 1):
  # Iterate through the entire train set
  for i, (x_batch, y_batch) in enumerate(trainloader):
    x_batch, y_batch = x_batch.to(device), y_batch.to(device)  # Move the data to the device that is used

    optimizer.zero_grad()  # Set all currenly stored gradients to zero 

    y_pred = model(x_batch.view(-1, w * h * c))

    loss = criterion(y_pred, y_batch)

    loss.backward()

    optimizer.step()

    # Compute relevant metrics
        
    y_pred_max = torch.argmax(y_pred, dim=1)  # Get the labels with highest output probability

    correct = torch.sum(torch.eq(y_pred_max, y_batch)).item()  # Count how many are equal to the true labels

    elapsed = time.time() - start  # Keep track of how much time has elapsed

    # Show progress every 20 batches 
    if not i % 20:
      print(f'epoch: {epoch}, time: {elapsed:.3f}s, loss: {loss.item():.3f}, train accuracy: {correct / batch_size:.3f}')
    
  # Evaluate the model on the test set
  correct_total = 0
  for i, (x_batch, y_batch) in enumerate(testloader):
    x_batch, y_batch = x_batch.to(device), y_batch.to(device)  # Move the data to the device that is used

    y_pred = model(x_batch.view(-1, w * h * c))
    y_pred_max = torch.argmax(y_pred, dim=1)

    correct_total += torch.sum(torch.eq(y_pred_max, y_batch)).item()

  print(f'Test accuracy: {correct_total / len(testset.data):.3f}')
# Out:
# epoch: 1, time: 0.028s, loss: 2.285, train accuracy: 0.148
# epoch: 1, time: 0.400s, loss: 2.208, train accuracy: 0.234
# epoch: 1, time: 0.743s, loss: 2.203, train accuracy: 0.188
# epoch: 1, time: 1.100s, loss: 2.143, train accuracy: 0.188
# epoch: 1, time: 1.456s, loss: 2.008, train accuracy: 0.297
# epoch: 1, time: 1.801s, loss: 1.972, train accuracy: 0.375
# epoch: 1, time: 2.152s, loss: 1.956, train accuracy: 0.297
# epoch: 1, time: 2.516s, loss: 1.854, train accuracy: 0.336
# epoch: 1, time: 2.860s, loss: 1.887, train accuracy: 0.367
# epoch: 1, time: 3.207s, loss: 1.929, train accuracy: 0.328
# epoch: 1, time: 3.573s, loss: 1.795, train accuracy: 0.344
# epoch: 1, time: 3.917s, loss: 1.943, train accuracy: 0.383
# epoch: 1, time: 4.307s, loss: 1.806, train accuracy: 0.383
# epoch: 1, time: 4.671s, loss: 1.845, train accuracy: 0.367
# epoch: 1, time: 5.015s, loss: 1.822, train accuracy: 0.297
# epoch: 1, time: 5.385s, loss: 1.809, train accuracy: 0.391
# epoch: 1, time: 5.770s, loss: 1.686, train accuracy: 0.430
# epoch: 1, time: 6.224s, loss: 1.794, train accuracy: 0.359
# epoch: 1, time: 6.650s, loss: 1.871, train accuracy: 0.367
# epoch: 1, time: 7.004s, loss: 1.658, train accuracy: 0.414
# Test accuracy: 0.397
# epoch: 2, time: 8.543s, loss: 1.794, train accuracy: 0.359
# epoch: 2, time: 8.929s, loss: 1.633, train accuracy: 0.516
# epoch: 2, time: 9.292s, loss: 1.656, train accuracy: 0.461
# epoch: 2, time: 9.649s, loss: 1.660, train accuracy: 0.445
# epoch: 2, time: 10.021s, loss: 1.651, train accuracy: 0.469
# epoch: 2, time: 10.375s, loss: 1.593, train accuracy: 0.438
# epoch: 2, time: 10.722s, loss: 1.642, train accuracy: 0.430
# epoch: 2, time: 11.092s, loss: 1.688, train accuracy: 0.414
# epoch: 2, time: 11.476s, loss: 1.732, train accuracy: 0.391
# epoch: 2, time: 11.822s, loss: 1.642, train accuracy: 0.383
# epoch: 2, time: 12.193s, loss: 1.568, train accuracy: 0.406
# epoch: 2, time: 12.549s, loss: 1.702, train accuracy: 0.383
# epoch: 2, time: 12.893s, loss: 1.791, train accuracy: 0.352
# epoch: 2, time: 13.274s, loss: 1.555, train accuracy: 0.477
# epoch: 2, time: 13.635s, loss: 1.612, train accuracy: 0.492
# epoch: 2, time: 13.994s, loss: 1.645, train accuracy: 0.391
# epoch: 2, time: 14.411s, loss: 1.476, train accuracy: 0.477
# epoch: 2, time: 14.759s, loss: 1.578, train accuracy: 0.383
# epoch: 2, time: 15.123s, loss: 1.518, train accuracy: 0.508
# epoch: 2, time: 15.482s, loss: 1.582, train accuracy: 0.391
# Test accuracy: 0.443
# epoch: 3, time: 16.993s, loss: 1.461, train accuracy: 0.484
# epoch: 3, time: 17.379s, loss: 1.754, train accuracy: 0.328
# epoch: 3, time: 17.735s, loss: 1.542, train accuracy: 0.438
# epoch: 3, time: 18.089s, loss: 1.596, train accuracy: 0.438
# epoch: 3, time: 18.463s, loss: 1.458, train accuracy: 0.484
# epoch: 3, time: 18.834s, loss: 1.420, train accuracy: 0.508
# epoch: 3, time: 19.184s, loss: 1.425, train accuracy: 0.500
# epoch: 3, time: 19.558s, loss: 1.704, train accuracy: 0.383
# epoch: 3, time: 19.912s, loss: 1.439, train accuracy: 0.523
# epoch: 3, time: 20.257s, loss: 1.525, train accuracy: 0.398
# epoch: 3, time: 20.620s, loss: 1.551, train accuracy: 0.445
# epoch: 3, time: 20.968s, loss: 1.553, train accuracy: 0.531
# epoch: 3, time: 21.312s, loss: 1.503, train accuracy: 0.492
# epoch: 3, time: 21.680s, loss: 1.419, train accuracy: 0.492
# epoch: 3, time: 22.025s, loss: 1.501, train accuracy: 0.492
# epoch: 3, time: 22.368s, loss: 1.613, train accuracy: 0.445
# epoch: 3, time: 22.743s, loss: 1.488, train accuracy: 0.484
# epoch: 3, time: 23.086s, loss: 1.529, train accuracy: 0.461
# epoch: 3, time: 23.439s, loss: 1.580, train accuracy: 0.414
# epoch: 3, time: 23.802s, loss: 1.434, train accuracy: 0.422
# Test accuracy: 0.471
# epoch: 4, time: 25.288s, loss: 1.584, train accuracy: 0.406
# epoch: 4, time: 25.640s, loss: 1.635, train accuracy: 0.414
# epoch: 4, time: 25.996s, loss: 1.449, train accuracy: 0.477
# epoch: 4, time: 26.340s, loss: 1.537, train accuracy: 0.484
# epoch: 4, time: 26.685s, loss: 1.384, train accuracy: 0.484
# epoch: 4, time: 27.057s, loss: 1.434, train accuracy: 0.461
# epoch: 4, time: 27.404s, loss: 1.490, train accuracy: 0.438
# epoch: 4, time: 27.758s, loss: 1.493, train accuracy: 0.438
# epoch: 4, time: 28.116s, loss: 1.324, train accuracy: 0.523
# epoch: 4, time: 28.484s, loss: 1.508, train accuracy: 0.508
# epoch: 4, time: 28.855s, loss: 1.492, train accuracy: 0.500
# epoch: 4, time: 29.203s, loss: 1.429, train accuracy: 0.484
# epoch: 4, time: 29.547s, loss: 1.335, train accuracy: 0.562
# epoch: 4, time: 29.929s, loss: 1.445, train accuracy: 0.453
# epoch: 4, time: 30.280s, loss: 1.583, train accuracy: 0.500
# epoch: 4, time: 30.622s, loss: 1.406, train accuracy: 0.484
# epoch: 4, time: 30.990s, loss: 1.649, train accuracy: 0.438
# epoch: 4, time: 31.333s, loss: 1.501, train accuracy: 0.469
# epoch: 4, time: 31.686s, loss: 1.461, train accuracy: 0.469
# epoch: 4, time: 32.047s, loss: 1.425, train accuracy: 0.500
# Test accuracy: 0.480
# epoch: 5, time: 33.529s, loss: 1.397, train accuracy: 0.477
# epoch: 5, time: 33.879s, loss: 1.438, train accuracy: 0.469
# epoch: 5, time: 34.254s, loss: 1.516, train accuracy: 0.461
# epoch: 5, time: 34.605s, loss: 1.329, train accuracy: 0.477
# epoch: 5, time: 34.952s, loss: 1.364, train accuracy: 0.562
# epoch: 5, time: 35.304s, loss: 1.402, train accuracy: 0.539
# epoch: 5, time: 35.646s, loss: 1.251, train accuracy: 0.586
# epoch: 5, time: 36.053s, loss: 1.525, train accuracy: 0.477
# epoch: 5, time: 36.429s, loss: 1.601, train accuracy: 0.391
# epoch: 5, time: 36.809s, loss: 1.415, train accuracy: 0.453
# epoch: 5, time: 37.171s, loss: 1.416, train accuracy: 0.500
# epoch: 5, time: 37.530s, loss: 1.466, train accuracy: 0.477
# epoch: 5, time: 37.883s, loss: 1.262, train accuracy: 0.539
# epoch: 5, time: 38.252s, loss: 1.649, train accuracy: 0.406
# epoch: 5, time: 38.617s, loss: 1.274, train accuracy: 0.555
# epoch: 5, time: 39.011s, loss: 1.395, train accuracy: 0.508
# epoch: 5, time: 39.354s, loss: 1.375, train accuracy: 0.555
# epoch: 5, time: 39.706s, loss: 1.306, train accuracy: 0.602
# epoch: 5, time: 40.060s, loss: 1.434, train accuracy: 0.484
# epoch: 5, time: 40.404s, loss: 1.372, train accuracy: 0.523
# Test accuracy: 0.495
# epoch: 6, time: 41.922s, loss: 1.538, train accuracy: 0.484
# epoch: 6, time: 42.272s, loss: 1.299, train accuracy: 0.523
# epoch: 6, time: 42.644s, loss: 1.343, train accuracy: 0.547
# epoch: 6, time: 42.994s, loss: 1.225, train accuracy: 0.531
# epoch: 6, time: 43.338s, loss: 1.289, train accuracy: 0.594
# epoch: 6, time: 43.695s, loss: 1.441, train accuracy: 0.531
# epoch: 6, time: 44.056s, loss: 1.425, train accuracy: 0.500
# epoch: 6, time: 44.449s, loss: 1.412, train accuracy: 0.461
# epoch: 6, time: 44.803s, loss: 1.288, train accuracy: 0.500
# epoch: 6, time: 45.154s, loss: 1.294, train accuracy: 0.539
# epoch: 6, time: 45.493s, loss: 1.551, train accuracy: 0.453
# epoch: 6, time: 45.842s, loss: 1.358, train accuracy: 0.547
# epoch: 6, time: 46.199s, loss: 1.304, train accuracy: 0.539
# epoch: 6, time: 46.545s, loss: 1.241, train accuracy: 0.531
# epoch: 6, time: 46.920s, loss: 1.312, train accuracy: 0.516
# epoch: 6, time: 47.286s, loss: 1.469, train accuracy: 0.492
# epoch: 6, time: 47.637s, loss: 1.421, train accuracy: 0.523
# epoch: 6, time: 48.009s, loss: 1.371, train accuracy: 0.508
# epoch: 6, time: 48.368s, loss: 1.304, train accuracy: 0.578
# epoch: 6, time: 48.730s, loss: 1.232, train accuracy: 0.539
# Test accuracy: 0.504
# epoch: 7, time: 50.253s, loss: 1.316, train accuracy: 0.500
# epoch: 7, time: 50.595s, loss: 1.403, train accuracy: 0.492
# epoch: 7, time: 50.937s, loss: 1.291, train accuracy: 0.531
# epoch: 7, time: 51.308s, loss: 1.342, train accuracy: 0.539
# epoch: 7, time: 51.651s, loss: 1.306, train accuracy: 0.594
# epoch: 7, time: 51.992s, loss: 1.169, train accuracy: 0.602
# epoch: 7, time: 52.363s, loss: 1.268, train accuracy: 0.547
# epoch: 7, time: 52.713s, loss: 1.148, train accuracy: 0.648
# epoch: 7, time: 53.054s, loss: 1.338, train accuracy: 0.484
# epoch: 7, time: 53.414s, loss: 1.223, train accuracy: 0.633
# epoch: 7, time: 53.758s, loss: 1.347, train accuracy: 0.562
# epoch: 7, time: 54.102s, loss: 1.249, train accuracy: 0.547
# epoch: 7, time: 54.467s, loss: 1.232, train accuracy: 0.578
# epoch: 7, time: 54.820s, loss: 1.350, train accuracy: 0.547
# epoch: 7, time: 55.176s, loss: 1.465, train accuracy: 0.469
# epoch: 7, time: 55.547s, loss: 1.266, train accuracy: 0.539
# epoch: 7, time: 55.891s, loss: 1.054, train accuracy: 0.648
# epoch: 7, time: 56.244s, loss: 1.475, train accuracy: 0.484
# epoch: 7, time: 56.602s, loss: 1.353, train accuracy: 0.562
# epoch: 7, time: 56.948s, loss: 1.354, train accuracy: 0.523
# Test accuracy: 0.516
# epoch: 8, time: 58.424s, loss: 1.227, train accuracy: 0.562
# epoch: 8, time: 58.774s, loss: 1.055, train accuracy: 0.656
# epoch: 8, time: 59.116s, loss: 1.347, train accuracy: 0.531
# epoch: 8, time: 59.465s, loss: 1.235, train accuracy: 0.562
# epoch: 8, time: 59.825s, loss: 1.282, train accuracy: 0.523
# epoch: 8, time: 60.170s, loss: 1.423, train accuracy: 0.523
# epoch: 8, time: 60.516s, loss: 1.328, train accuracy: 0.523
# epoch: 8, time: 60.870s, loss: 1.168, train accuracy: 0.648
# epoch: 8, time: 61.208s, loss: 1.310, train accuracy: 0.492
# epoch: 8, time: 61.560s, loss: 1.287, train accuracy: 0.586
# epoch: 8, time: 61.918s, loss: 1.253, train accuracy: 0.531
# epoch: 8, time: 62.273s, loss: 1.160, train accuracy: 0.609
# epoch: 8, time: 62.625s, loss: 1.374, train accuracy: 0.523
# epoch: 8, time: 62.981s, loss: 0.972, train accuracy: 0.664
# epoch: 8, time: 63.338s, loss: 1.176, train accuracy: 0.617
# epoch: 8, time: 63.694s, loss: 1.238, train accuracy: 0.500
# epoch: 8, time: 64.049s, loss: 1.233, train accuracy: 0.547
# epoch: 8, time: 64.452s, loss: 1.234, train accuracy: 0.531
# epoch: 8, time: 64.805s, loss: 1.362, train accuracy: 0.586
# epoch: 8, time: 65.158s, loss: 1.160, train accuracy: 0.594
# Test accuracy: 0.509
# epoch: 9, time: 66.729s, loss: 1.385, train accuracy: 0.523
# epoch: 9, time: 67.078s, loss: 1.349, train accuracy: 0.531
# epoch: 9, time: 67.432s, loss: 1.261, train accuracy: 0.578
# epoch: 9, time: 67.775s, loss: 1.074, train accuracy: 0.625
# epoch: 9, time: 68.148s, loss: 1.138, train accuracy: 0.586
# epoch: 9, time: 68.554s, loss: 1.275, train accuracy: 0.531
# epoch: 9, time: 68.958s, loss: 1.314, train accuracy: 0.516
# epoch: 9, time: 69.318s, loss: 1.198, train accuracy: 0.562
# epoch: 9, time: 69.674s, loss: 1.195, train accuracy: 0.555
# epoch: 9, time: 70.026s, loss: 1.243, train accuracy: 0.602
# epoch: 9, time: 70.382s, loss: 1.197, train accuracy: 0.570
# epoch: 9, time: 70.732s, loss: 1.216, train accuracy: 0.578
# epoch: 9, time: 71.075s, loss: 1.207, train accuracy: 0.586
# epoch: 9, time: 71.460s, loss: 1.209, train accuracy: 0.562
# epoch: 9, time: 71.809s, loss: 1.267, train accuracy: 0.578
# epoch: 9, time: 72.159s, loss: 1.455, train accuracy: 0.477
# epoch: 9, time: 72.511s, loss: 1.127, train accuracy: 0.617
# epoch: 9, time: 72.860s, loss: 1.316, train accuracy: 0.508
# epoch: 9, time: 73.199s, loss: 1.469, train accuracy: 0.508
# epoch: 9, time: 73.553s, loss: 1.035, train accuracy: 0.656
# Test accuracy: 0.514
# epoch: 10, time: 75.053s, loss: 1.288, train accuracy: 0.523
# epoch: 10, time: 75.410s, loss: 1.250, train accuracy: 0.555
# epoch: 10, time: 75.764s, loss: 1.282, train accuracy: 0.617
# epoch: 10, time: 76.107s, loss: 1.167, train accuracy: 0.570
# epoch: 10, time: 76.479s, loss: 1.368, train accuracy: 0.516
# epoch: 10, time: 76.829s, loss: 1.216, train accuracy: 0.578
# epoch: 10, time: 77.173s, loss: 1.069, train accuracy: 0.664
# epoch: 10, time: 77.523s, loss: 1.313, train accuracy: 0.500
# epoch: 10, time: 77.875s, loss: 1.189, train accuracy: 0.523
# epoch: 10, time: 78.221s, loss: 1.196, train accuracy: 0.555
# epoch: 10, time: 78.618s, loss: 1.300, train accuracy: 0.562
# epoch: 10, time: 78.965s, loss: 1.175, train accuracy: 0.555
# epoch: 10, time: 79.307s, loss: 1.104, train accuracy: 0.586
# epoch: 10, time: 79.666s, loss: 1.179, train accuracy: 0.594
# epoch: 10, time: 80.020s, loss: 1.126, train accuracy: 0.570
# epoch: 10, time: 80.380s, loss: 1.202, train accuracy: 0.539
# epoch: 10, time: 80.769s, loss: 1.245, train accuracy: 0.586
# epoch: 10, time: 81.126s, loss: 1.016, train accuracy: 0.664
# epoch: 10, time: 81.471s, loss: 1.130, train accuracy: 0.609
# epoch: 10, time: 81.827s, loss: 1.054, train accuracy: 0.672
# Test accuracy: 0.517
