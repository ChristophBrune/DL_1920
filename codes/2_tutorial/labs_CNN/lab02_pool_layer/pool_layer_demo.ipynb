# %% [markdown]
# # Lab 10.02 : Pooling layer - demo

# %%
import torch
import torch.nn as nn

# %% [markdown]
# ### Make a pooling module
# * inputs:  activation maps of size n x n
# * output:  activation maps of size n/p x n/p
# * p: pooling size

# %%
mod = nn.MaxPool2d(2,2)

# %% [markdown]
# ### Make an input 2 x 6 x 6  (two channels, each one has 6 x 6 pixels )

# %%
bs=1

x=torch.rand(bs,2,6,6)


print(x)
print(x.size())
# Out:
# tensor([[[[7.8584e-01, 4.3157e-02, 4.5878e-01, 8.7239e-01, 3.5576e-01,
#            2.0779e-02],
#           [3.3146e-04, 2.4983e-01, 1.0933e-01, 6.6911e-01, 8.7198e-01,
#            5.4535e-01],
#           [3.8105e-01, 7.7947e-01, 9.9660e-01, 1.9689e-01, 6.7197e-01,
#            5.4963e-01],
#           [7.7655e-01, 4.6209e-01, 4.9587e-01, 4.9105e-01, 2.6531e-01,
#            5.7209e-02],
#           [6.7581e-01, 7.6080e-01, 6.3998e-02, 1.0210e-01, 3.0605e-01,
#            3.5578e-01],
#           [2.6869e-01, 4.7699e-01, 4.3309e-01, 1.7795e-01, 5.0348e-01,
#            4.0163e-01]],
#
#          [[8.7682e-01, 5.1493e-01, 8.2308e-01, 3.1562e-01, 3.9689e-01,
#            7.4478e-01],
#           [4.7252e-01, 5.1961e-01, 1.7332e-01, 6.6967e-01, 6.6433e-01,
#            8.5564e-02],
#           [3.0257e-01, 9.7056e-01, 9.3324e-01, 9.4362e-01, 9.1904e-01,
#            4.7380e-01],
#           [7.3981e-01, 2.3189e-01, 6.1621e-01, 2.0459e-01, 4.1996e-01,
#            8.4740e-01],
#           [9.9794e-01, 5.7874e-01, 9.5154e-01, 1.2416e-01, 7.3158e-01,
#            2.7759e-02],
#           [2.1623e-01, 1.2058e-02, 4.8932e-01, 4.5349e-01, 6.4915e-01,
#            2.6605e-01]]]])
# torch.Size([1, 2, 6, 6])

# %% [markdown]
# ### Feed it to the pooling layer: the output size should be divided by 2

# %%
y=mod(x)

print(y)
print(y.size())
# Out:
# tensor([[[[0.7858, 0.8724, 0.8720],
#           [0.7795, 0.9966, 0.6720],
#           [0.7608, 0.4331, 0.5035]],
#
#          [[0.8768, 0.8231, 0.7448],
#           [0.9706, 0.9436, 0.9190],
#           [0.9979, 0.9515, 0.7316]]]])
# torch.Size([1, 2, 3, 3])
